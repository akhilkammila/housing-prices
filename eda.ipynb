# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ptitprince as pt

# %%
# Import dataset
train_path = "./data/train.csv"
df = pd.read_csv(train_path)
df.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
df.describe().T
# Out:
#                 count           mean  ...        75%       max
# Id             1460.0     730.500000  ...    1095.25    1460.0
# MSSubClass     1460.0      56.897260  ...      70.00     190.0
# LotFrontage    1201.0      70.049958  ...      80.00     313.0
# LotArea        1460.0   10516.828082  ...   11601.50  215245.0
# OverallQual    1460.0       6.099315  ...       7.00      10.0
# OverallCond    1460.0       5.575342  ...       6.00       9.0
# YearBuilt      1460.0    1971.267808  ...    2000.00    2010.0
# YearRemodAdd   1460.0    1984.865753  ...    2004.00    2010.0
# MasVnrArea     1452.0     103.685262  ...     166.00    1600.0
# BsmtFinSF1     1460.0     443.639726  ...     712.25    5644.0
# BsmtFinSF2     1460.0      46.549315  ...       0.00    1474.0
# BsmtUnfSF      1460.0     567.240411  ...     808.00    2336.0
# TotalBsmtSF    1460.0    1057.429452  ...    1298.25    6110.0
# 1stFlrSF       1460.0    1162.626712  ...    1391.25    4692.0
# ...

# %%
# Split into categorical and numerical, and graph appropriately
# Categorical: raincloud plot (scatter + box + density plot)
# Numerical: regression plot (scatter + regression line)

categorical_vars = [
    'MSSubClass', 'MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
    'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
    'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
    'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
    'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical',
    'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
    'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition'
]

numerical_vars = [
    'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
    'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF',
    '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
    'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt',
    'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
    'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice'
]

len(categorical_vars), len(numerical_vars)
# Out:
# (44, 36)

# %%
# Graph categorical variables
width = 3
categorical_vars = categorical_vars
fig, axs = plt.subplots(nrows=(len(categorical_vars)+width-1)//width, ncols=width, figsize=(15,70))

for index, var in enumerate(categorical_vars):
    row = index//width
    col = index % width

    pt.RainCloud(df[var], df['SalePrice'], ax=axs[row,col], pointplot=True, box_showfliers=False)

# %%
width=3
numerical_vars = numerical_vars

fig, axs = plt.subplots(nrows=(len(numerical_vars)+width-1)//width, ncols=width, figsize=(15,50))

for index, var in enumerate(numerical_vars):
    row = index//width
    col = index % width

    sns.regplot(df[var], df['SalePrice'], ax=axs[row,col])

# %%
plt.hist(df['SalePrice'])
df['SalePrice'].describe().T
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64
